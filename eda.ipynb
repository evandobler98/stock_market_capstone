# %%
import pandas as pd

df = pd.read_excel("Stock Price Data.xlsx")
print(df.shape)
df.head()
# Out:
# (10060, 10)
#   Stock       Date  Close/Last    Volume    Open    High     Low    7 Day MA  \
# 0  AAPL 2025-07-11      211.16  39765810  210.57  212.13  209.86  211.522857
# 1  AAPL 2025-07-10      212.41  44443640  210.51  213.48  210.03  211.045714
# 2  AAPL 2025-07-09      211.14  48749370  209.53  211.33  207.22  210.011429
# 3  AAPL 2025-07-08      210.01  42848930  210.10  211.43  208.45  208.574286
# 4  AAPL 2025-07-07      209.95  50228980  212.68  216.23  208.80  207.287143
#
#     14 Day MA  1 Month MA
# 0  207.077857  203.883333
# 1  206.352143  203.444583
# 2  205.221429  203.045000
# 3  204.114286  202.717083
# 4  203.286429  202.370833

# %%
print("Column names:", df.columns.tolist())
print("\nData types:")
print(df.dtypes)

print("\nMissing values per column:")
print(df.isna().sum())
# Out:
# Column names: ['Stock', 'Date', 'Close/Last', 'Volume', 'Open', 'High', 'Low', '7 Day MA', '14 Day MA', '1 Month MA']
#
# Data types:
# Stock                 object
# Date          datetime64[ns]
# Close/Last           float64
# Volume                 int64
# Open                 float64
# High                 float64
# Low                  float64
# 7 Day MA             float64
# 14 Day MA            float64
# 1 Month MA           float64
# dtype: object
#
# Missing values per column:
# Stock         0
# Date          0
# Close/Last    0
# Volume        0
# Open          0
# High          0
# Low           0
# 7 Day MA      0
# 14 Day MA     0
# 1 Month MA    0
# dtype: int64

# %%
print("\nSample data:")
display(df.head())
# Out:
# Sample data:
#   Stock       Date  Close/Last    Volume    Open    High     Low    7 Day MA  \
# 0  AAPL 2025-07-11      211.16  39765810  210.57  212.13  209.86  211.522857
# 1  AAPL 2025-07-10      212.41  44443640  210.51  213.48  210.03  211.045714
# 2  AAPL 2025-07-09      211.14  48749370  209.53  211.33  207.22  210.011429
# 3  AAPL 2025-07-08      210.01  42848930  210.10  211.43  208.45  208.574286
# 4  AAPL 2025-07-07      209.95  50228980  212.68  216.23  208.80  207.287143
#
#     14 Day MA  1 Month MA
# 0  207.077857  203.883333
# 1  206.352143  203.444583
# 2  205.221429  203.045000
# 3  204.114286  202.717083
# 4  203.286429  202.370833

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
print("\nDate conversion - null dates:", df['Date'].isna().sum())
# Out:
# Date conversion - null dates: 0

# %%
price_cols = ['Close/Last', 'Open', 'High', 'Low']

for col in price_cols:
    df[col] = df[col].astype(str).str.replace(',', '').str.replace('$', '').str.strip()
    df[col] = pd.to_numeric(df[col], errors='coerce')

print("\nAfter cleaning price columns:")
print(df[price_cols].head())

for col in price_cols:
    print(f"{col} - missing after conversion:", df[col].isna().sum())
# Out:
# After cleaning price columns:
#    Close/Last    Open    High     Low
# 0      211.16  210.57  212.13  209.86
# 1      212.41  210.51  213.48  210.03
# 2      211.14  209.53  211.33  207.22
# 3      210.01  210.10  211.43  208.45
# 4      209.95  212.68  216.23  208.80
# Close/Last - missing after conversion: 0
# Open - missing after conversion: 0
# High - missing after conversion: 0
# Low - missing after conversion: 0

# %%
df['Year'] = df['Date'].dt.year
print(df['Year'].head())
# Out:
# 0    2025
# 1    2025
# 2    2025
# 3    2025
# 4    2025
# Name: Year, dtype: int32

# %%
print("\nSummary statistics:")
display(df.describe())
# Out:
# Summary statistics:
#                                 Date    Close/Last        Volume  \
# count                          10060  10060.000000  1.006000e+04
# mean   2020-07-08 07:40:20.516898560    138.939068  8.161268e+07
# min              2015-07-13 00:00:00      9.580000  7.164543e+06
# 25%              2018-01-08 00:00:00     46.887500  3.791698e+07
# 50%              2020-07-09 00:00:00    120.655000  6.719858e+07
# 75%              2023-01-06 00:00:00    201.397500  1.044772e+08
# max              2025-07-11 00:00:00    503.510000  9.140809e+08
# std                              NaN    106.761561  6.314621e+07
#
#                Open          High           Low      7 Day MA     14 Day MA  \
# count  10060.000000  10060.000000  10060.000000  10060.000000  10060.000000
# mean     138.906327    140.764714    136.989527    138.604928    138.216780
# min        9.490000     10.330000      9.400000     10.087143     10.786429
# 25%       46.810000     47.287500     46.440000     46.820714     46.466786
# 50%      120.500000    122.145000    118.935000    119.806429    118.942857
# 75%      200.755000    204.335000    198.270000    201.441429    201.313214
# max      503.050000    506.780000    499.740000    498.940000    495.986429
# std      106.756626    108.193914    105.254075    106.489375    106.187534
#
#          1 Month MA          Year
# count  10060.000000  10060.000000
# mean     137.665327   2020.016700
# min       11.525417   2015.000000
# 25%       46.217604   2018.000000
# 50%      118.900000   2020.000000
# 75%      200.506146   2023.000000
# max      487.463750   2025.000000
# std      105.756593      2.914379

# %%
print("\nUnique stocks:", df['Stock'].unique())
print("Date range:", df['Date'].min(), "to", df['Date'].max())
# Out:
# Unique stocks: ['AAPL' 'TSLA' 'MSFT' 'AMZN']
# Date range: 2015-07-13 00:00:00 to 2025-07-11 00:00:00

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style for plots
sns.set_style('whitegrid')
# %matplotlib inline

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Close/Last'].dropna(), bins=50, kde=True)
plt.title('Distribution of Close Prices')
plt.xlabel('Close Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(14,7))
for stock in df['Stock'].unique():
    stock_data = df[df['Stock'] == stock]
    plt.plot(stock_data['Date'], stock_data['Close/Last'], label=stock)

plt.title('Close Price Over Time by Stock')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
avg_year_stock = df.groupby(['Year', 'Stock'])['Close/Last'].mean().reset_index()

plt.figure(figsize=(12,6))
sns.barplot(data=avg_year_stock, x='Year', y='Close/Last', hue='Stock')
plt.title('Average Close Price per Year by Stock')
plt.xticks(rotation=45)
plt.ylabel('Average Close Price')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Stock', y='Close/Last', data=df)
plt.title('Close Price Distribution by Stock')
plt.show()
